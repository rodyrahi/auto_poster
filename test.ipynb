# %%
# from openai import OpenAI
# api_key = ''
# client = OpenAI(api_key=api_key)
# object = 'star'
# prompt = f"""
# Produce PNG images of {object} with a crisp white background. 
# These images should be high-quality vector graphics, suitable for integration into presentations, 
# videos, and other visual media. The generator should offer a diverse range of objects, from everyday 
# items to abstract shapes, allowing users to customize their visuals with ease. Ensure the output images 
# maintain sharpness and clarity, making them ideal for professional use in a variety of contexts.
# """
# response = client.images.generate(
#   model="dall-e-3",
#   prompt=prompt,
#   size="1024x1024",
#   quality="standard",
#   n=4,
# )
# image_url = response.data[0].url

# %%
# import requests

# # Save the image
# image_data = requests.get(image_url).content
# saved_image_path = f"Downloaded_images/{object}.png"
# with open(saved_image_path, "wb") as file:
#     file.write(image_data)

# import rembg
# import numpy as np
# from PIL import Image

# # Load the input image
# input_image = Image.open(saved_image_path)

# # Convert the input image to a numpy array
# input_array = np.array(input_image)

# # Apply background removal using rembg
# output_array = rembg.remove(input_array)

# # Create a PIL Image from the output array
# output_image = Image.fromarray(output_array)

# # Save the output image
# output_image.save(saved_image_path)

# %%
# from PIL import Image
# import requests
# from io import BytesIO

# url =  image_url

# response = requests.get(url)
# image_bytes = BytesIO(response.content)
# img = Image.open(image_bytes)
# img.save('downloaded_image.jpg')

# %%
# !python -m BingImageCreator -U '1XWj9KTI-9pYvVdUvC2ZA4OOrm2BwMXV9aN_Tp4aZ3RLg4E-BrAAjk3dI543IFFWrOfBtIcTSlfvN3-MpX0z5s9VzEyuHTlRhBPVwNOP_dmJUCz7oiCbo5tbS-WLoTP6oCAcQeHgQDiiUw8__tSHIbygIDeie7leZUFfU2LyIyr7IDWUe8Z1jygNTqxeSLbHlak7N65tbpdu8ocWGlkSxUA' --prompt 'drawhorse' --output-dir 'D:\auto_poster\zoomin'
# Out:
# Sending request...
# ERROR: <!DOCTYPE html><html dir="ltr" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:Web="http://schemas.live.com/Web/"><script type="text/javascript" nonce="79YYFPT54kRR7Bpzk4ld5GmiW2TGfp9SO6BNiaFFaRs=" >//<![CDATA[
#
# si_ST=new Date
#
# ...

# %%
import BingImageCreator

# %%
BingImageCreator.
